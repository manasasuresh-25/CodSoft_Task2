# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cleaned data.csv')

# %%
" gives information no.of rows and columns"
df.shape
# Out:
# (5333, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5333 entries, 0 to 5332
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          5333 non-null   object
#  1   title         5333 non-null   object
#  2   director      5333 non-null   object
#  3   cast          5333 non-null   object
#  4   country       5333 non-null   object
#  5   release_year  5333 non-null   int64
#  6   duration      5333 non-null   object
#  7   listed_in     5333 non-null   object
#  8   description   5333 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 375.1+ KB

# %%
df.head()
# Out:
#       type                          title             director  \
# 0    Movie                        Sankofa         Haile Gerima
# 1  TV Show  The Great British Baking Show      Andy Devonshire
# 2    Movie                   The Starling       Theodore Melfi
# 3    Movie                   Je Suis Karl  Christian Schwochow
# 4    Movie                          Jeans           S. Shankar
#
#                                                 cast  \
# 0  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 1  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 2  Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 3  Luna Wedler, Jannis Niew̦hner, Milan Peschel,...
# 4  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                              country  release_year   duration  \
# 0  United States, Ghana, Burkina Faso, United Kin...          1993    125 min
# 1                                     United Kingdom          2021  9 Seasons
# ...

# %%
df.describe()
# Out:
#        release_year
# count   5333.000000
# mean    2012.742546
# std        9.624978
# min     1942.000000
# 25%     2011.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2021.000000

# %%
df["type"].value_counts()/100
# Out:
# type
# Movie      51.86
# TV Show     1.47
# Name: count, dtype: float64

# %%
df['release_year'].value_counts().sort_index()
# Out:
# release_year
# 1942      1
# 1944      1
# 1945      1
# 1946      1
# 1947      1
#        ...
# 2017    657
# 2018    648
# 2019    519
# 2020    442
# 2021    161
# Name: count, Length: 72, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States                                   1846
# India                                            875
# United Kingdom                                   183
# Canada                                           107
# Spain                                             91
#                                                 ...
# Uruguay, Guatemala                                 1
# Romania, Bulgaria, Hungary                         1
# Philippines, United States                         1
# India, United Kingdom, Canada, United States       1
# United Arab Emirates, Jordan                       1
# Name: count, Length: 604, dtype: int64

# %%
df["listed_in"].value_counts()
# Out:
# listed_in
# Dramas, International Movies                               336
# Stand-Up Comedy                                            286
# Comedies, Dramas, International Movies                     257
# Dramas, Independent Movies, International Movies           243
# Children & Family Movies, Comedies                         179
#                                                           ...
# Comedies, Documentaries                                      1
# International TV Shows, Romantic TV Shows, TV Mysteries      1
# Horror Movies, International Movies, Sci-Fi & Fantasy        1
# Reality TV                                                   1
# Cult Movies, Dramas, Thrillers                               1
# Name: count, Length: 335, dtype: int64

# %%
pd.crosstab(df["country"], df["type"]).head(10)
# Out:
# type                                                Movie  TV Show
# country
# , France, Algeria                                       1        0
# Argentina                                              34        1
# Argentina, Brazil, France, Poland, Germany, Den...      1        0
# Argentina, Chile                                        2        0
# Argentina, Chile, Peru                                  1        0
# Argentina, France                                       1        0
# Argentina, France, United States, Germany, Qatar        1        0
# Argentina, Spain                                        7        0
# Argentina, United States                                1        0
# Argentina, Uruguay, Serbia                              1        0

# %%
pd.crosstab(df["release_year"], df["type"])
# Out:
# type          Movie  TV Show
# release_year
# 1942              1        0
# 1944              1        0
# 1945              1        0
# 1946              1        0
# 1947              1        0
# ...             ...      ...
# 2017            640       17
# 2018            632       16
# 2019            495       24
# 2020            409       33
# 2021            146       15
#
# [72 rows x 2 columns]

# %%
pd.crosstab(df["listed_in"], df["type"]).head(10)
# Out:
# type                                                Movie  TV Show
# listed_in
# Action & Adventure                                    127        0
# Action & Adventure, Anime Features, Children & ...      4        0
# Action & Adventure, Anime Features, Classic Movies      1        0
# Action & Adventure, Anime Features, Horror Movies       1        0
# Action & Adventure, Anime Features, Internation...     33        0
# Action & Adventure, Anime Features, Sci-Fi & Fa...      4        0
# Action & Adventure, Children & Family Movies            1        0
# Action & Adventure, Children & Family Movies, C...      4        0
# Action & Adventure, Children & Family Movies, C...      5        0
# Action & Adventure, Children & Family Movies, C...      1        0

# %%
'outliner'
plt.figure(figsize=(8,5))
sns.boxplot(x=df["release_year"])
plt.title("Boxplot of Release Year")
plt.show()

# %%
pd.crosstab(df["duration"], df["type"]).head(10)
# Out:
# type      Movie  TV Show
# duration
# 1 Season      0      106
# 100 min      90        0
# 101 min     104        0
# 102 min     112        0
# 103 min     101        0
# 104 min      99        0
# 105 min      90        0
# 106 min      99        0
# 107 min      86        0
# 108 min      77        0
